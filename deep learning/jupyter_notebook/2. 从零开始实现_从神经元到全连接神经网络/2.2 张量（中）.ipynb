# %% [markdown]
# # 2.1 张量（中）

# %% [markdown]
# 在上一节中，我们用回归模型实现了一个简单的函数拟合，同时介绍了一些神经网络的基本概念。在本节，我们将探索神经网络更具有泛化的模型编写，同时实现更多基于pytorch这一由Meta（Facebook母公司）开发的深度学习框架的底层实现（这个框架的所有算法都由c/c++编写，再跟python代码绑定），我们将重点实现这一框架独有的动态图，这一有别于其余深度学习框架（Tensorflow）的静态图的独特实现。

# %% [markdown]
# ## 数字
# 首先我们实现一个数字类，这个类有一个更独特的学名：张量（Tensor）

# %%
class Tensor:
    def __init__(self, data):
        self.data = data

    def __add__(self, other):
        out = Tensor(self.data + other.data)
        return out

    def __mul__(self, other):
        out = Tensor(self.data * other.data)
        return out
    
    def __repr__(self):
        return f"Tensor(data={self.data})"

# %% [markdown]
# 我们定义了一个名叫Tensor的类。实现了针对加法和乘法的运算符重载，同时我们还实现了魔术方法\_\_repr\_\_用于打印我们的结果，我们来测试一下这个类：

# %%
a = Tensor(12)
b = Tensor(15)
print(a + b)
print(a * b)
# Out:
# Tensor(data=27)
# Tensor(data=180)

# %% [markdown]
# 回顾上一节我们代码实现反向传播的过程，我们都是首先计算一个损失函数，获得以可训练参数作为自变量的函数，然后对每个可训练参数计算偏导数，最后再计算用这个偏导数乘上步长，用来计算这次迭代后可训练参数的结果

# %% [markdown]
# 同时，根据链式法则，我们并不需要一口气就算出某个可训练参数的偏导数，我们可以用递归的方式逐层求偏导，算出这个可训练参数的偏导数，现在让我们修改这段代码，先算出这些基本运算符的导数，用于后续的递归

# %%
class Tensor:
    def __init__(self, data):
        self.data = data
        self.grad = 0.0
        self._backward = lambda: None

    def __add__(self, other):
        # 如果被加数还不是Tensor类，就将其转化成Tensor类
        if isinstance(other, (int, float)):
            other = Tensor(other)
        out = Tensor(self.data + other.data)
        def _backward():
            self.grad += 1.0 * out.grad
            other.grad += 1.0 * out.grad
        out._backward = _backward
        return out

    def __mul__(self, other):
        # 如果被乘数还不是Tensor类，就将其转化成Tensor类
        if isinstance(other, (int, float)):
            other = Tensor(other)
        out = Tensor(self.data * other.data)
        def _backward():
            self.grad += other.data * out.grad
            other.grad += self.data * out.grad
        out._backward = _backward
        return out
    
    def __repr__(self):
        return f"Tensor(data={self.data})"

# %% [markdown]
# (ps: grad是累加的，因为一个Tensor可能被用于计算多个Tensor的值)

# %% [markdown]
# 让我们来测试一个一个函数f(x)=a*b+c，当a=10,b=5,c=10时，分别计算f(x)对a,b,c的偏导，可以很容易的算出(∂f/∂a) = 5,(∂f/∂b) = 10, (∂f/∂c) = 1

# %%
a = Tensor(10)
b = Tensor(5)
c = Tensor(10)
d = a*b
e = d+c
e.grad=1
e._backward()
print(d.grad)
print(c.grad)
d._backward()
print(a.grad)
print(b.grad)
# Out:
# 1.0
# 1.0
# 5.0
# 10.0

# %% [markdown]
# 现在，我们需要实现反向传播算法，我们需要保证算式计算偏导数的先后顺序，我们必须保证在链式法则中，算式中后算的值的偏导数被先算出来。其实熟悉算法的同学应该能知道我们需要用什么算法实现这一功能了，那就是拓扑排序。

# %% [markdown]
# ## 拓扑排序
# 在计算机科学领域，有向图的拓扑排序（英语：Topological sorting）或拓扑测序（英语：Topological ordering）是对其顶点的一种线性排序，使得对于从顶点u 到顶点v的每个有向边uv，u 在排序中都在v之前。我们来实现Tensor类的反向传播算法，同时因为我们的反向传播是在整个算式算到最外面开始的，为了确保反向传播的顺序，我们需要在等式计算的时候，记录下通过计算得到当前值的tensor序列，我们用_prev表示

# %%
class Tensor:
    def __init__(self, data, _prev=()):
        self.data = data
        self.grad = 0.0
        self._backward = lambda: None
        self._prev = set(_prev)

    def __add__(self, other):
        # 如果被加数还不是Tensor类，就将其转化成Tensor类
        if isinstance(other, (int, float)):
            other = Tensor(other)
        out = Tensor(self.data + other.data, (self, other))
        def _backward():
            self.grad += 1.0 * out.grad
            other.grad += 1.0 * out.grad
        out._backward = _backward
        return out

    def __mul__(self, other):
        # 如果被乘数还不是Tensor类，就将其转化成Tensor类
        if isinstance(other, (int, float)):
            other = Tensor(other)
        out = Tensor(self.data * other.data, (self, other))
        def _backward():
            self.grad += other.data * out.grad
            other.grad += self.data * out.grad
        out._backward = _backward
        return out
    
    def backward(self):
    
        topo = []
        # 记录下已访问过的Tensor集合
        visited = set()
        def build_topo(v):
            if v not in visited:
                visited.add(v)
                for child in v._prev:
                    build_topo(child)
                topo.append(v)
        build_topo(self)
        # 因为上面得到的topo序列顺序是反的，所以我们在逐步计算偏导数时需要先进行逆序操作
        self.grad = 1.0
        for node in reversed(topo):
            node._backward()
    
    def __repr__(self):
        return f"Tensor(data={self.data})"

# %% [markdown]
# 让我们再测试一遍函数f(x)=a*b+c，当a=10,b=5,c=10时，分别计算f(x)对a,b,c的偏导，可以很容易的算出(∂f/∂a) = 5,(∂f/∂b) = 10, (∂f/∂c) = 1

# %%
a = Tensor(10)
b = Tensor(5)
c = Tensor(10)
e = a*b+c
e.backward()
print(a.grad)
print(b.grad)
print(c.grad)
# Out:
# 5.0
# 10.0
# 1.0

# %% [markdown]
# 现在，我们大体上已经实现了一个Tensor类，我们现在还需要补上激活函数：tanh, sigmoid和relu，以及梯度下降迭代法（就是把之前算出来的梯度按照某种策略对可训练参数进行迭代），同时我们还需要补充左加号,减号和真除等基本魔术方法（参考加法，乘法的实现，不然会报错），让我们的程序可以更好的跑起来，来实现我们上一节的遗留问题

# %%
import math
class Tensor:
    def __init__(self, data, _prev=()):
        self.data = data
        self.grad = 0.0
        self._backward = lambda: None
        self._prev = set(_prev)

    def __add__(self, other):
        if isinstance(other, (int, float)):
            other = Tensor(other)
        out = Tensor(self.data + other.data, (self, other))
        def _backward():
            self.grad += 1.0 * out.grad
            other.grad += 1.0 * out.grad
        out._backward = _backward
        return out
    
    def __radd__(self, other):
        return self.__add__(other)

    def __sub__(self, other):
        if isinstance(other, (int, float)):
            other = Tensor(other)
        out = Tensor(self.data - other.data, (self, other))
        def _backward():
            self.grad += 1.0 * out.grad
            other.grad -= 1.0 * out.grad  # Subtract gradient for the other operand
        out._backward = _backward
        return out

    def __rsub__(self, other):
        return (-self).__add__(other)
    
    # 必须重写负号，否则(-self)会报错
    def __neg__(self):
        # Negation operation
        neg_tensor = Tensor(-self.data, (self,))
        def _backward():
            self.grad -= 1.0 * neg_tensor.grad  
        neg_tensor._backward = _backward
        return neg_tensor

    def __mul__(self, other):
        if isinstance(other, (int, float)):
            other = Tensor(other)
        out = Tensor(self.data * other.data, (self, other))
        def _backward():
            self.grad += other.data * out.grad
            other.grad += self.data * out.grad
        out._backward = _backward
        return out
    
    def __truediv__(self, other):
        if isinstance(other, (int, float)):
            other = Tensor(other)
        out = Tensor(self.data / other.data)
        def _backward():
            self.grad += (1 / other.data) * out.grad
            other.grad -= (self.data / (other.data ** 2)) * out.grad
        out._backward = _backward
        return out
    
    def tanh(self):
        x = self.data
        t = (math.exp(2*x) - 1)/(math.exp(2*x) + 1)
        out = Tensor(t, (self, ))
        
        def _backward():
            self.grad += (1 - t**2) * out.grad
        out._backward = _backward
        
        return out
    
    def sigmoid(self):
        x = self.data
        s = 1 / (1 + math.exp(-x))
        out = Tensor(s, (self,))

        def _backward():
            self.grad += (s * (1 - s)) * out.grad
        out._backward = _backward

        return out

    def relu(self):
        x = self.data
        r = max(0, x)
        out = Tensor(r, (self,))

        def _backward():
            self.grad += (1 if x > 0 else 0) * out.grad
        out._backward = _backward

        return out
    
    def gradient_descent_opt(self, learning_rate=0.001, grad_zero=True):
        for v in self.visited:
            v.data -= learning_rate * v.grad
            if grad_zero:
                v.grad = 0

    def backward(self, ):
        topo = []
        # 记录下已访问过的Tensor集合
        self.visited = set()
        def build_topo(v):
            if v not in self.visited:
                self.visited.add(v)
                for child in v._prev:
                    build_topo(child)
                topo.append(v)
        build_topo(self)
        # 因为上面得到的topo序列顺序是反的，所以我们在逐步计算偏导数时需要先进行逆序操作
        self.grad = 1.0
        for node in reversed(topo):
            node._backward()
    
    def __repr__(self):
        return f"Tensor(data={self.data})"

# %%
a = Tensor(10)
b = Tensor(5)
c = Tensor(10)
e = a*b+c
e.backward()
print(a.grad)
print(b.grad)
print(c.grad)
e.gradient_descent_opt()
print(a,a.grad)
print(b,b.grad)
print(c,c.grad)
# Out:
# 5.0
# 10.0
# 1.0
# Tensor(data=9.995) 0
# Tensor(data=4.99) 0
# Tensor(data=9.999) 0

# %% [markdown]
# 此外，我们还需要设置，哪些量是可训练的，哪些量是不可训练的，如果一个数被自动转化成Tensor类,那么我们默认是不可训练的数。

# %%
import math
class Tensor:
    def __init__(self, data, _prev=(), trainable=True):
        self.data = data
        self.grad = 0.0
        self._backward = lambda: None
        self._prev = set(_prev)
        self.trainable=trainable

    def __add__(self, other):
        if isinstance(other, (int, float)):
            other = Tensor(other, trainable=False)
        out = Tensor(self.data + other.data, (self, other))
        def _backward():
            self.grad += 1.0 * out.grad
            other.grad += 1.0 * out.grad
        out._backward = _backward
        return out
    
    def __radd__(self, other):
        return self.__add__(other)

    def __sub__(self, other):
        if isinstance(other, (int, float)):
            other = Tensor(other, trainable=False)
        out = Tensor(self.data - other.data, (self, other))
        def _backward():
            self.grad += 1.0 * out.grad
            other.grad -= 1.0 * out.grad  # Subtract gradient for the other operand
        out._backward = _backward
        return out

    def __rsub__(self, other):
        return (-self).__add__(other)
    
    # 必须重写负号，否则(-self)会报错
    def __neg__(self):
        # Negation operation
        neg_tensor = Tensor(-self.data, (self,))
        def _backward():
            self.grad -= 1.0 * neg_tensor.grad  
        neg_tensor._backward = _backward
        return neg_tensor

    def __mul__(self, other):
        if isinstance(other, (int, float)):
            other = Tensor(other, trainable=False)
        out = Tensor(self.data * other.data, (self, other))
        def _backward():
            self.grad += other.data * out.grad
            other.grad += self.data * out.grad
        out._backward = _backward
        return out
    
    def __truediv__(self, other):
        if isinstance(other, (int, float)):
            other = Tensor(other, trainable=False)
        out = Tensor(self.data / other.data, (self, other))
        def _backward():
            self.grad += (1 / other.data) * out.grad
            other.grad -= (self.data / (other.data ** 2)) * out.grad
        out._backward = _backward
        return out
    
    # 必须重写平方项，不能用乘以自身表示平方，否则求导会错
    def __pow__(self, power):
        out = Tensor(self.data ** power, (self,))
        def _backward():
            self.grad += power * (self.data ** (power - 1)) * out.grad
        out._backward = _backward
        return out
    
    def tanh(self):
        x = self.data
        t = (math.exp(2*x) - 1)/(math.exp(2*x) + 1)
        out = Tensor(t, (self, ))
        
        def _backward():
            self.grad += (1 - t**2) * out.grad
        out._backward = _backward
        
        return out
    
    def sigmoid(self):
        x = self.data
        s = 1 / (1 + math.exp(-x))
        out = Tensor(s, (self,))

        def _backward():
            self.grad += (s * (1 - s)) * out.grad
        out._backward = _backward

        return out

    def relu(self):
        x = self.data
        r = max(0, x)
        out = Tensor(r, (self,))

        def _backward():
            self.grad += (1 if x > 0 else 0) * out.grad
        out._backward = _backward

        return out
    
    def gradient_descent_opt(self, learning_rate=0.001, grad_zero=True):
        for v in self.visited:
            if v.trainable:
                v.data -= learning_rate * v.grad
            if grad_zero:
                v.grad = 0

    def backward(self, ):
        topo = []
        # 记录下已访问过的Tensor集合
        self.visited = set()
        def build_topo(v):
            if v not in self.visited:
                self.visited.add(v)
                for child in v._prev:
                    build_topo(child)
                topo.append(v)
        build_topo(self)
        # 因为上面得到的topo序列顺序是反的，所以我们在逐步计算偏导数时需要先进行逆序操作
        self.grad = 1.0
        for node in reversed(topo):
            node._backward()
    
    def __repr__(self):
        return f"Tensor(data={self.data}, trainable={self.trainable})"

# %% [markdown]
# 我们先测试一个简单的函数，来求解它的神经网络表示

# %%
a=Tensor(3)
b=Tensor(2)
def func(x):
    return a*x+b

# %%
training_data = [[1,5],[2,6]]

# %%
def print_tensor(t, blank=""):
    print(blank+repr(t)+f" grad:{t.grad}")
    for temp in t._prev:
        print_tensor(temp, blank+"----")

# %%
epoch = 2000
for i in range(epoch):
    loss = 0
    for data in training_data:
        loss += (func(data[0])-data[1])**2
    loss = loss/len(training_data)
    loss.backward()
    print_tensor(loss)
    loss.gradient_descent_opt(learning_rate=0.1)
    if i % 10 == 0:
        print(f'Epoch {i}/{epoch}, Loss: {loss}')
# Out:
# Tensor(data=1.6320743268117513e-26, trainable=True) grad:1.0
# ----Tensor(data=2, trainable=False) grad:-8.160371634058757e-27
# ----Tensor(data=3.2641486536235026e-26, trainable=True) grad:0.5
# --------Tensor(data=2.3609818032359662e-26, trainable=True) grad:0.5
# ------------Tensor(data=0, trainable=False) grad:0.5
# ------------Tensor(data=2.3609818032359662e-26, trainable=True) grad:0.5
# ----------------Tensor(data=-1.5365486660812167e-13, trainable=True) grad:-1.5365486660812167e-13
# --------------------Tensor(data=5, trainable=False) grad:1.5365486660812167e-13
# --------------------Tensor(data=4.999999999999846, trainable=True) grad:-1.5365486660812167e-13
# ------------------------Tensor(data=3.999999999999598, trainable=True) grad:-5.861977570020827e-14
# ------------------------Tensor(data=1.0000000000002485, trainable=True) grad:-1.5365486660812167e-13
# ----------------------------Tensor(data=1.0000000000002485, trainable=True) grad:3.6415315207705135e-14
# ----------------------------Tensor(data=1, trainable=False) grad:-1.5365486660815983e-13
# --------Tensor(data=9.031668503875364e-27, trainable=True) grad:0.5
# ------------Tensor(data=9.50350909079134e-14, trainable=True) grad:9.50350909079134e-14
# ----------------Tensor(data=6, trainable=False) grad:-9.50350909079134e-14
# ----------------Tensor(data=6.000000000000095, trainable=True) grad:9.50350909079134e-14
# --------------------Tensor(data=3.999999999999598, trainable=True) grad:-5.861977570020827e-14
# --------------------Tensor(data=2.000000000000497, trainable=True) grad:9.50350909079134e-14
# ------------------------Tensor(data=2, trainable=False) grad:9.503509090793702e-14
# ------------------------Tensor(data=1.0000000000002485, trainable=True) grad:3.6415315207705135e-14
# Epoch 0/2000, Loss: Tensor(data=-0.1, trainable=True)
# Tensor(data=1.5830860645975265e-26, trainable=True) grad:1.0
# ----Tensor(data=2, trainable=False) grad:-7.915430322987632e-27
# ----Tensor(data=3.166172129195053e-26, trainable=True) grad:0.5
# --------Tensor(data=2.279808016088724e-26, trainable=True) grad:0.5
# ------------Tensor(data=0, trainable=False) grad:0.5
# ------------Tensor(data=2.279808016088724e-26, trainable=True) grad:0.5
# ----------------Tensor(data=-1.509903313490213e-13, trainable=True) grad:-1.509903313490213e-13
# --------------------Tensor(data=4.999999999999849, trainable=True) grad:-1.509903313490213e-13
# ------------------------Tensor(data=3.999999999999604, trainable=True) grad:-5.684341886080802e-14
# ------------------------Tensor(data=1.000000000000245, trainable=True) grad:-1.509903313490213e-13
# ----------------------------Tensor(data=1, trainable=False) grad:-1.5099033134905827e-13
# ----------------------------Tensor(data=1.000000000000245, trainable=True) grad:3.730349362740526e-14
# --------------------Tensor(data=5, trainable=False) grad:1.509903313490213e-13
# --------Tensor(data=8.863641131063289e-27, trainable=True) grad:0.5
# ------------Tensor(data=9.414691248821327e-14, trainable=True) grad:9.414691248821327e-14
# ----------------Tensor(data=6.000000000000094, trainable=True) grad:9.414691248821327e-14
# --------------------Tensor(data=3.999999999999604, trainable=True) grad:-5.684341886080802e-14
# --------------------Tensor(data=2.00000000000049, trainable=True) grad:9.414691248821327e-14
# ------------------------Tensor(data=2, trainable=False) grad:9.414691248823633e-14
# ------------------------Tensor(data=1.000000000000245, trainable=True) grad:3.730349362740526e-14
# ----------------Tensor(data=6, trainable=False) grad:-9.414691248821327e-14
# Tensor(data=1.539856486991415e-26, trainable=True) grad:1.0
# ----Tensor(data=3.07971297398283e-26, trainable=True) grad:0.5
# --------Tensor(data=8.532319550870464e-27, trainable=True) grad:0.5
# ------------Tensor(data=9.237055564881302e-14, trainable=True) grad:9.237055564881302e-14
# ----------------Tensor(data=6, trainable=False) grad:-9.237055564881302e-14
# ----------------Tensor(data=6.000000000000092, trainable=True) grad:9.237055564881302e-14
# --------------------Tensor(data=3.9999999999996096, trainable=True) grad:-5.684341886080802e-14
# --------------------Tensor(data=2.0000000000004823, trainable=True) grad:9.237055564881302e-14
# ------------------------Tensor(data=1.0000000000002411, trainable=True) grad:3.552713678800501e-14
# ------------------------Tensor(data=2, trainable=False) grad:9.23705556488353e-14
# --------Tensor(data=2.2264810188957837e-26, trainable=True) grad:0.5
# ------------Tensor(data=2.2264810188957837e-26, trainable=True) grad:0.5
# ----------------Tensor(data=-1.4921397450962104e-13, trainable=True) grad:-1.4921397450962104e-13
# --------------------Tensor(data=5, trainable=False) grad:1.4921397450962104e-13
# --------------------Tensor(data=4.999999999999851, trainable=True) grad:-1.4921397450962104e-13
# ------------------------Tensor(data=1.0000000000002411, trainable=True) grad:-1.4921397450962104e-13
# ----------------------------Tensor(data=1, trainable=False) grad:-1.49213974509657e-13
# ----------------------------Tensor(data=1.0000000000002411, trainable=True) grad:3.552713678800501e-14
# ------------------------Tensor(data=3.9999999999996096, trainable=True) grad:-5.684341886080802e-14
# ------------Tensor(data=0, trainable=False) grad:0.5
# ----Tensor(data=2, trainable=False) grad:-7.699282434957075e-27
# Tensor(data=1.4972579981094804e-26, trainable=True) grad:1.0
# ----Tensor(data=2, trainable=False) grad:-7.486289990547402e-27
# ----Tensor(data=2.994515996218961e-26, trainable=True) grad:0.5
# --------Tensor(data=8.207308857919407e-27, trainable=True) grad:0.5
# ------------Tensor(data=9.059419880941277e-14, trainable=True) grad:9.059419880941277e-14
# ----------------Tensor(data=6.000000000000091, trainable=True) grad:9.059419880941277e-14
# --------------------Tensor(data=3.9999999999996154, trainable=True) grad:-5.684341886080802e-14
# --------------------Tensor(data=2.000000000000475, trainable=True) grad:9.059419880941277e-14
# ------------------------Tensor(data=1.0000000000002376, trainable=True) grad:3.375077994860476e-14
# ------------------------Tensor(data=2, trainable=False) grad:9.05941988094343e-14
# ----------------Tensor(data=6, trainable=False) grad:-9.059419880941277e-14
# --------Tensor(data=2.17378511042702e-26, trainable=True) grad:0.5
# ------------Tensor(data=2.17378511042702e-26, trainable=True) grad:0.5
# ----------------Tensor(data=-1.474376176702208e-13, trainable=True) grad:-1.474376176702208e-13
# --------------------Tensor(data=5, trainable=False) grad:1.474376176702208e-13
# --------------------Tensor(data=4.999999999999853, trainable=True) grad:-1.474376176702208e-13
# ------------------------Tensor(data=3.9999999999996154, trainable=True) grad:-5.684341886080802e-14
# ------------------------Tensor(data=1.0000000000002376, trainable=True) grad:-1.474376176702208e-13
# ----------------------------Tensor(data=1, trainable=False) grad:-1.4743761767025583e-13
# ----------------------------Tensor(data=1.0000000000002376, trainable=True) grad:3.375077994860476e-14
# ------------Tensor(data=0, trainable=False) grad:0.5
# Tensor(data=1.4503207742488302e-26, trainable=True) grad:1.0
# ----Tensor(data=2.9006415484976604e-26, trainable=True) grad:0.5
# --------Tensor(data=2.0959245390817063e-26, trainable=True) grad:0.5
# ------------Tensor(data=0, trainable=False) grad:0.5
# ------------Tensor(data=2.0959245390817063e-26, trainable=True) grad:0.5
# ----------------Tensor(data=-1.4477308241112041e-13, trainable=True) grad:-1.4477308241112041e-13
# --------------------Tensor(data=4.999999999999855, trainable=True) grad:-1.4477308241112041e-13
# ------------------------Tensor(data=3.999999999999621, trainable=True) grad:-5.5067062021407764e-14
# ------------------------Tensor(data=1.0000000000002343, trainable=True) grad:-1.4477308241112041e-13
# ----------------------------Tensor(data=1, trainable=False) grad:-1.4477308241115431e-13
# ----------------------------Tensor(data=1.0000000000002343, trainable=True) grad:3.4638958368304884e-14
# --------------------Tensor(data=5, trainable=False) grad:1.4477308241112041e-13
# --------Tensor(data=8.047170094159541e-27, trainable=True) grad:0.5
# ------------Tensor(data=8.970602038971265e-14, trainable=True) grad:8.970602038971265e-14
# ----------------Tensor(data=6, trainable=False) grad:-8.970602038971265e-14
# ----------------Tensor(data=6.00000000000009, trainable=True) grad:8.970602038971265e-14
# --------------------Tensor(data=2.0000000000004685, trainable=True) grad:8.970602038971265e-14
# ------------------------Tensor(data=2, trainable=False) grad:8.970602038973366e-14
# ------------------------Tensor(data=1.0000000000002343, trainable=True) grad:3.4638958368304884e-14
# --------------------Tensor(data=3.999999999999621, trainable=True) grad:-5.5067062021407764e-14
# ----Tensor(data=2, trainable=False) grad:-7.251603871244151e-27
# Tensor(data=1.4089844628152492e-26, trainable=True) grad:1.0
# ----Tensor(data=2, trainable=False) grad:-7.044922314076246e-27
# ----Tensor(data=2.8179689256304984e-26, trainable=True) grad:0.5
# --------Tensor(data=7.731625732071137e-27, trainable=True) grad:0.5
# ------------Tensor(data=8.79296635503124e-14, trainable=True) grad:8.79296635503124e-14
# ----------------Tensor(data=6, trainable=False) grad:-8.79296635503124e-14
# ----------------Tensor(data=6.000000000000088, trainable=True) grad:8.79296635503124e-14
# --------------------Tensor(data=3.9999999999996265, trainable=True) grad:-5.5067062021407764e-14
# --------------------Tensor(data=2.0000000000004614, trainable=True) grad:8.79296635503124e-14
# ------------------------Tensor(data=2, trainable=False) grad:8.792966355033268e-14
# ------------------------Tensor(data=1.0000000000002307, trainable=True) grad:3.2862601528904634e-14
# --------Tensor(data=2.0448063524233847e-26, trainable=True) grad:0.5
# ------------Tensor(data=2.0448063524233847e-26, trainable=True) grad:0.5
# ----------------Tensor(data=-1.4299672557172016e-13, trainable=True) grad:-1.4299672557172016e-13
# --------------------Tensor(data=4.999999999999857, trainable=True) grad:-1.4299672557172016e-13
# ------------------------Tensor(data=1.0000000000002307, trainable=True) grad:-1.4299672557172016e-13
# ----------------------------Tensor(data=1, trainable=False) grad:-1.4299672557175316e-13
# ----------------------------Tensor(data=1.0000000000002307, trainable=True) grad:3.2862601528904634e-14
# ------------------------Tensor(data=3.9999999999996265, trainable=True) grad:-5.5067062021407764e-14
# --------------------Tensor(data=5, trainable=False) grad:1.4299672557172016e-13
# ------------Tensor(data=0, trainable=False) grad:0.5
# Tensor(data=1.3634671885839968e-26, trainable=True) grad:1.0
# ----Tensor(data=2.7269343771679936e-26, trainable=True) grad:0.5
# --------Tensor(data=7.576220133742597e-27, trainable=True) grad:0.5
# ------------Tensor(data=8.704148513061227e-14, trainable=True) grad:8.704148513061227e-14
# ----------------Tensor(data=6, trainable=False) grad:-8.704148513061227e-14
# ----------------Tensor(data=6.000000000000087, trainable=True) grad:8.704148513061227e-14
# --------------------Tensor(data=3.999999999999632, trainable=True) grad:-5.3290705182007514e-14
# --------------------Tensor(data=2.0000000000004547, trainable=True) grad:8.704148513061227e-14
# ------------------------Tensor(data=2, trainable=False) grad:8.704148513063206e-14
# ------------------------Tensor(data=1.0000000000002274, trainable=True) grad:3.375077994860476e-14
# --------Tensor(data=1.969312363793734e-26, trainable=True) grad:0.5
# ------------Tensor(data=1.969312363793734e-26, trainable=True) grad:0.5
# ----------------Tensor(data=-1.4033219031261979e-13, trainable=True) grad:-1.4033219031261979e-13
# --------------------Tensor(data=4.99999999999986, trainable=True) grad:-1.4033219031261979e-13
# ------------------------Tensor(data=3.999999999999632, trainable=True) grad:-5.3290705182007514e-14
# ------------------------Tensor(data=1.0000000000002274, trainable=True) grad:-1.4033219031261979e-13
# ----------------------------Tensor(data=1, trainable=False) grad:-1.403321903126517e-13
# ----------------------------Tensor(data=1.0000000000002274, trainable=True) grad:3.375077994860476e-14
# --------------------Tensor(data=5, trainable=False) grad:1.4033219031261979e-13
# ------------Tensor(data=0, trainable=False) grad:0.5
# ----Tensor(data=2, trainable=False) grad:-6.817335942919984e-27
# Tensor(data=1.3233930545987694e-26, trainable=True) grad:1.0
# ----Tensor(data=2, trainable=False) grad:-6.616965272993847e-27
# ----Tensor(data=2.646786109197539e-26, trainable=True) grad:0.5
# --------Tensor(data=7.270142102516845e-27, trainable=True) grad:0.5
# ------------Tensor(data=8.526512829121202e-14, trainable=True) grad:8.526512829121202e-14
# ----------------Tensor(data=6.000000000000085, trainable=True) grad:8.526512829121202e-14
# --------------------Tensor(data=3.999999999999637, trainable=True) grad:-5.3290705182007514e-14
# --------------------Tensor(data=2.000000000000448, trainable=True) grad:8.526512829121202e-14
# ------------------------Tensor(data=2, trainable=False) grad:8.526512829123113e-14
# ------------------------Tensor(data=1.000000000000224, trainable=True) grad:3.197442310920451e-14
# ----------------Tensor(data=6, trainable=False) grad:-8.526512829121202e-14
# --------Tensor(data=1.9197718989458543e-26, trainable=True) grad:0.5
# ------------Tensor(data=1.9197718989458543e-26, trainable=True) grad:0.5
# ----------------Tensor(data=-1.3855583347321954e-13, trainable=True) grad:-1.3855583347321954e-13
# --------------------Tensor(data=4.9999999999998614, trainable=True) grad:-1.3855583347321954e-13
# ------------------------Tensor(data=1.000000000000224, trainable=True) grad:-1.3855583347321954e-13
# ----------------------------Tensor(data=1, trainable=False) grad:-1.3855583347325059e-13
# ----------------------------Tensor(data=1.000000000000224, trainable=True) grad:3.197442310920451e-14
# ------------------------Tensor(data=3.999999999999637, trainable=True) grad:-5.3290705182007514e-14
# --------------------Tensor(data=5, trainable=False) grad:1.3855583347321954e-13
# ------------Tensor(data=0, trainable=False) grad:0.5
# Tensor(data=1.2914047448920574e-26, trainable=True) grad:1.0
# ----Tensor(data=2.5828094897841148e-26, trainable=True) grad:0.5
# --------Tensor(data=1.8708625228221516e-26, trainable=True) grad:0.5
# ------------Tensor(data=0, trainable=False) grad:0.5
# ------------Tensor(data=1.8708625228221516e-26, trainable=True) grad:0.5
# ----------------Tensor(data=-1.3677947663381929e-13, trainable=True) grad:-1.3677947663381929e-13
# --------------------Tensor(data=5, trainable=False) grad:1.3677947663381929e-13
# --------------------Tensor(data=4.999999999999863, trainable=True) grad:-1.3677947663381929e-13
# ------------------------Tensor(data=1.000000000000221, trainable=True) grad:-1.3677947663381929e-13
# ----------------------------Tensor(data=1, trainable=False) grad:-1.367794766338495e-13
# ----------------------------Tensor(data=1.000000000000221, trainable=True) grad:3.197442310920451e-14
# ------------------------Tensor(data=3.9999999999996425, trainable=True) grad:-5.240252676230739e-14
# --------Tensor(data=7.119469669619632e-27, trainable=True) grad:0.5
# ------------Tensor(data=8.43769498715119e-14, trainable=True) grad:8.43769498715119e-14
# ----------------Tensor(data=6.000000000000084, trainable=True) grad:8.43769498715119e-14
# --------------------Tensor(data=2.000000000000442, trainable=True) grad:8.43769498715119e-14
# ------------------------Tensor(data=1.000000000000221, trainable=True) grad:3.197442310920451e-14
# ------------------------Tensor(data=2, trainable=False) grad:8.437694987153054e-14
# --------------------Tensor(data=3.9999999999996425, trainable=True) grad:-5.240252676230739e-14
# ----------------Tensor(data=6, trainable=False) grad:-8.43769498715119e-14
# ----Tensor(data=2, trainable=False) grad:-6.457023724460287e-27
# Tensor(data=1.2478596229238575e-26, trainable=True) grad:1.0
# ----Tensor(data=2.495719245847715e-26, trainable=True) grad:0.5
# --------Tensor(data=6.97037495853286e-27, trainable=True) grad:0.5
# ------------Tensor(data=8.348877145181177e-14, trainable=True) grad:8.348877145181177e-14
# ----------------Tensor(data=6, trainable=False) grad:-8.348877145181177e-14
# ----------------Tensor(data=6.0000000000000835, trainable=True) grad:8.348877145181177e-14
# --------------------Tensor(data=2.0000000000004357, trainable=True) grad:8.348877145181177e-14
# ------------------------Tensor(data=1.0000000000002178, trainable=True) grad:3.2862601528904634e-14
# ------------------------Tensor(data=2, trainable=False) grad:8.348877145182996e-14
# --------------------Tensor(data=3.999999999999648, trainable=True) grad:-5.062616992290714e-14
# --------Tensor(data=1.798681749994429e-26, trainable=True) grad:0.5
# ------------Tensor(data=1.798681749994429e-26, trainable=True) grad:0.5
# ----------------Tensor(data=-1.341149413747189e-13, trainable=True) grad:-1.341149413747189e-13
# --------------------Tensor(data=4.999999999999866, trainable=True) grad:-1.341149413747189e-13
# ------------------------Tensor(data=3.999999999999648, trainable=True) grad:-5.062616992290714e-14
# ------------------------Tensor(data=1.0000000000002178, trainable=True) grad:-1.341149413747189e-13
# ----------------------------Tensor(data=1, trainable=False) grad:-1.3411494137474812e-13
# ----------------------------Tensor(data=1.0000000000002178, trainable=True) grad:3.2862601528904634e-14
# --------------------Tensor(data=5, trainable=False) grad:1.341149413747189e-13
# ------------Tensor(data=0, trainable=False) grad:0.5
# ----Tensor(data=2, trainable=False) grad:-6.2392981146192876e-27
# Tensor(data=1.2213144534631705e-26, trainable=True) grad:1.0
# ----Tensor(data=2.442628906926341e-26, trainable=True) grad:0.5
# --------Tensor(data=1.7749370367472766e-26, trainable=True) grad:0.5
# ------------Tensor(data=0, trainable=False) grad:0.5
# ------------Tensor(data=1.7749370367472766e-26, trainable=True) grad:0.5
# ----------------Tensor(data=-1.3322676295501878e-13, trainable=True) grad:-1.3322676295501878e-13
# --------------------Tensor(data=4.999999999999867, trainable=True) grad:-1.3322676295501878e-13
# ------------------------Tensor(data=1.0000000000002145, trainable=True) grad:-1.3322676295501878e-13
# ----------------------------Tensor(data=1.0000000000002145, trainable=True) grad:3.019806626980426e-14
# ----------------------------Tensor(data=1, trainable=False) grad:-1.3322676295504736e-13
# ------------------------Tensor(data=3.9999999999996527, trainable=True) grad:-5.1514348342607263e-14
# --------------------Tensor(data=5, trainable=False) grad:1.3322676295501878e-13
# --------Tensor(data=6.676918701790644e-27, trainable=True) grad:0.5
# ------------Tensor(data=8.171241461241152e-14, trainable=True) grad:8.171241461241152e-14
# ----------------Tensor(data=6.000000000000082, trainable=True) grad:8.171241461241152e-14
# --------------------Tensor(data=2.000000000000429, trainable=True) grad:8.171241461241152e-14
# ------------------------Tensor(data=2, trainable=False) grad:8.171241461242905e-14
# ------------------------Tensor(data=1.0000000000002145, trainable=True) grad:3.019806626980426e-14
# --------------------Tensor(data=3.9999999999996527, trainable=True) grad:-5.1514348342607263e-14
# ----------------Tensor(data=6, trainable=False) grad:-8.171241461241152e-14
# ----Tensor(data=2, trainable=False) grad:-6.1065722673158524e-27
# Epoch 10/2000, Loss: Tensor(data=-0.1, trainable=True)
# Tensor(data=1.1789526228528021e-26, trainable=True) grad:1.0
# ----Tensor(data=2.3579052457056043e-26, trainable=True) grad:0.5
# --------Tensor(data=6.532557156135199e-27, trainable=True) grad:0.5
# ------------Tensor(data=8.08242361927114e-14, trainable=True) grad:8.08242361927114e-14
# ----------------Tensor(data=6, trainable=False) grad:-8.08242361927114e-14
# ----------------Tensor(data=6.000000000000081, trainable=True) grad:8.08242361927114e-14
# --------------------Tensor(data=2.0000000000004228, trainable=True) grad:8.08242361927114e-14
# ------------------------Tensor(data=2, trainable=False) grad:8.082423619272849e-14
# ------------------------Tensor(data=1.0000000000002114, trainable=True) grad:3.108624468950438e-14
# --------------------Tensor(data=3.999999999999658, trainable=True) grad:-4.973799150320701e-14
# --------Tensor(data=1.7046495300920844e-26, trainable=True) grad:0.5
# ------------Tensor(data=1.7046495300920844e-26, trainable=True) grad:0.5
# ----------------Tensor(data=-1.305622276959184e-13, trainable=True) grad:-1.305622276959184e-13
# --------------------Tensor(data=4.999999999999869, trainable=True) grad:-1.305622276959184e-13
# ------------------------Tensor(data=3.999999999999658, trainable=True) grad:-4.973799150320701e-14
# ------------------------Tensor(data=1.0000000000002114, trainable=True) grad:-1.305622276959184e-13
# ----------------------------Tensor(data=1.0000000000002114, trainable=True) grad:3.108624468950438e-14
# ----------------------------Tensor(data=1, trainable=False) grad:-1.30562227695946e-13
# --------------------Tensor(data=5, trainable=False) grad:1.305622276959184e-13
# ------------Tensor(data=0, trainable=False) grad:0.5
# ----Tensor(data=2, trainable=False) grad:-5.894763114264011e-27
# Tensor(data=1.1487786932280984e-26, trainable=True) grad:1.0
# ----Tensor(data=2, trainable=False) grad:-5.743893466140492e-27
# ----Tensor(data=2.297557386456197e-26, trainable=True) grad:0.5
# --------Tensor(data=1.6585800532271773e-26, trainable=True) grad:0.5
# ------------Tensor(data=1.6585800532271773e-26, trainable=True) grad:0.5
# ----------------Tensor(data=-1.2878587085651816e-13, trainable=True) grad:-1.2878587085651816e-13
# --------------------Tensor(data=5, trainable=False) grad:1.2878587085651816e-13
# --------------------Tensor(data=4.999999999999871, trainable=True) grad:-1.2878587085651816e-13
# ------------------------Tensor(data=3.999999999999663, trainable=True) grad:-4.884981308350689e-14
# ------------------------Tensor(data=1.0000000000002083, trainable=True) grad:-1.2878587085651816e-13
# ----------------------------Tensor(data=1, trainable=False) grad:-1.28785870856545e-13
# ----------------------------Tensor(data=1.0000000000002083, trainable=True) grad:3.108624468950438e-14
# ------------Tensor(data=0, trainable=False) grad:0.5
# --------Tensor(data=6.3897733322901956e-27, trainable=True) grad:0.5
# ------------Tensor(data=7.993605777301127e-14, trainable=True) grad:7.993605777301127e-14
# ----------------Tensor(data=6, trainable=False) grad:-7.993605777301127e-14
# ----------------Tensor(data=6.00000000000008, trainable=True) grad:7.993605777301127e-14
# --------------------Tensor(data=2.0000000000004166, trainable=True) grad:7.993605777301127e-14
# ------------------------Tensor(data=2, trainable=False) grad:7.993605777302792e-14
# ------------------------Tensor(data=1.0000000000002083, trainable=True) grad:3.108624468950438e-14
# --------------------Tensor(data=3.999999999999663, trainable=True) grad:-4.884981308350689e-14
# Tensor(data=1.1120177750447993e-26, trainable=True) grad:1.0
# ----Tensor(data=2.2240355500895986e-26, trainable=True) grad:0.5
# --------Tensor(data=6.1089388500315154e-27, trainable=True) grad:0.5
# ------------Tensor(data=7.815970093361102e-14, trainable=True) grad:7.815970093361102e-14
# ----------------Tensor(data=6.000000000000078, trainable=True) grad:7.815970093361102e-14
# --------------------Tensor(data=2.0000000000004103, trainable=True) grad:7.815970093361102e-14
# ------------------------Tensor(data=2, trainable=False) grad:7.815970093362705e-14
# ------------------------Tensor(data=1.0000000000002052, trainable=True) grad:2.930988785010413e-14
# --------------------Tensor(data=3.999999999999668, trainable=True) grad:-4.884981308350689e-14
# ----------------Tensor(data=6, trainable=False) grad:-7.815970093361102e-14
# --------Tensor(data=1.613141665086447e-26, trainable=True) grad:0.5
# ------------Tensor(data=0, trainable=False) grad:0.5
# ------------Tensor(data=1.613141665086447e-26, trainable=True) grad:0.5
# ----------------Tensor(data=-1.270095140171179e-13, trainable=True) grad:-1.270095140171179e-13
# --------------------Tensor(data=4.999999999999873, trainable=True) grad:-1.270095140171179e-13
# ------------------------Tensor(data=3.999999999999668, trainable=True) grad:-4.884981308350689e-14
# ------------------------Tensor(data=1.0000000000002052, trainable=True) grad:-1.270095140171179e-13
# ----------------------------Tensor(data=1, trainable=False) grad:-1.2700951401714396e-13
# ----------------------------Tensor(data=1.0000000000002052, trainable=True) grad:2.930988785010413e-14
# --------------------Tensor(data=5, trainable=False) grad:1.270095140171179e-13
# ----Tensor(data=2, trainable=False) grad:-5.5600888752239965e-27
# Tensor(data=1.0827115924158387e-26, trainable=True) grad:1.0
# ----Tensor(data=2, trainable=False) grad:-5.4135579620791935e-27
# ----Tensor(data=2.1654231848316774e-26, trainable=True) grad:0.5
# --------Tensor(data=5.970888191617838e-27, trainable=True) grad:0.5
# ------------Tensor(data=7.72715225139109e-14, trainable=True) grad:7.72715225139109e-14
# ----------------Tensor(data=6.000000000000077, trainable=True) grad:7.72715225139109e-14
# --------------------Tensor(data=3.9999999999996727, trainable=True) grad:-4.796163466380676e-14
# --------------------Tensor(data=2.0000000000004046, trainable=True) grad:7.72715225139109e-14
# ------------------------Tensor(data=2, trainable=False) grad:7.727152251392652e-14
# ------------------------Tensor(data=1.0000000000002023, trainable=True) grad:2.930988785010413e-14
# ----------------Tensor(data=6, trainable=False) grad:-7.72715225139109e-14
# --------Tensor(data=1.5683343656698936e-26, trainable=True) grad:0.5
# ------------Tensor(data=0, trainable=False) grad:0.5
# ------------Tensor(data=1.5683343656698936e-26, trainable=True) grad:0.5
# ----------------Tensor(data=-1.2523315717771766e-13, trainable=True) grad:-1.2523315717771766e-13
# --------------------Tensor(data=4.999999999999875, trainable=True) grad:-1.2523315717771766e-13
# ------------------------Tensor(data=1.0000000000002023, trainable=True) grad:-1.2523315717771766e-13
# ----------------------------Tensor(data=1, trainable=False) grad:-1.25233157177743e-13
# ----------------------------Tensor(data=1.0000000000002023, trainable=True) grad:2.930988785010413e-14
# ------------------------Tensor(data=3.9999999999996727, trainable=True) grad:-4.796163466380676e-14
# --------------------Tensor(data=5, trainable=False) grad:1.2523315717771766e-13
# Tensor(data=1.0428741167021776e-26, trainable=True) grad:1.0
# ----Tensor(data=2, trainable=False) grad:-5.214370583510888e-27
# ----Tensor(data=2.0857482334043552e-26, trainable=True) grad:0.5
# --------Tensor(data=1.502306707902895e-26, trainable=True) grad:0.5
# ------------Tensor(data=1.502306707902895e-26, trainable=True) grad:0.5
# ----------------Tensor(data=-1.2256862191861728e-13, trainable=True) grad:-1.2256862191861728e-13
# --------------------Tensor(data=4.999999999999877, trainable=True) grad:-1.2256862191861728e-13
# ------------------------Tensor(data=3.9999999999996776, trainable=True) grad:-4.618527782440651e-14
# ------------------------Tensor(data=1.0000000000001994, trainable=True) grad:-1.2256862191861728e-13
# ----------------------------Tensor(data=1.0000000000001994, trainable=True) grad:3.019806626980426e-14
# ----------------------------Tensor(data=1, trainable=False) grad:-1.2256862191864172e-13
# --------------------Tensor(data=5, trainable=False) grad:1.2256862191861728e-13
# ------------Tensor(data=0, trainable=False) grad:0.5
# --------Tensor(data=5.834415255014603e-27, trainable=True) grad:0.5
# ------------Tensor(data=7.638334409421077e-14, trainable=True) grad:7.638334409421077e-14
# ----------------Tensor(data=6, trainable=False) grad:-7.638334409421077e-14
# ----------------Tensor(data=6.000000000000076, trainable=True) grad:7.638334409421077e-14
# --------------------Tensor(data=3.9999999999996776, trainable=True) grad:-4.618527782440651e-14
# --------------------Tensor(data=2.000000000000399, trainable=True) grad:7.638334409421077e-14
# ------------------------Tensor(data=1.0000000000001994, trainable=True) grad:3.019806626980426e-14
# ------------------------Tensor(data=2, trainable=False) grad:7.6383344094226e-14
# Tensor(data=1.0186166438666315e-26, trainable=True) grad:1.0
# ----Tensor(data=2, trainable=False) grad:-5.0930832193331575e-27
# ----Tensor(data=2.037233287733263e-26, trainable=True) grad:0.5
# --------Tensor(data=1.480613033009317e-26, trainable=True) grad:0.5
# ------------Tensor(data=1.480613033009317e-26, trainable=True) grad:0.5
# ----------------Tensor(data=-1.2168044349891716e-13, trainable=True) grad:-1.2168044349891716e-13
# --------------------Tensor(data=5, trainable=False) grad:1.2168044349891716e-13
# --------------------Tensor(data=4.999999999999878, trainable=True) grad:-1.2168044349891716e-13
# ------------------------Tensor(data=3.999999999999682, trainable=True) grad:-4.707345624410664e-14
# ------------------------Tensor(data=1.0000000000001963, trainable=True) grad:-1.2168044349891716e-13
# ----------------------------Tensor(data=1, trainable=False) grad:-1.2168044349894104e-13
# ----------------------------Tensor(data=1.0000000000001963, trainable=True) grad:2.7533531010703882e-14
# ------------Tensor(data=0, trainable=False) grad:0.5
# --------Tensor(data=5.566202547239459e-27, trainable=True) grad:0.5
# ------------Tensor(data=7.460698725481052e-14, trainable=True) grad:7.460698725481052e-14
# ----------------Tensor(data=6.000000000000075, trainable=True) grad:7.460698725481052e-14
# --------------------Tensor(data=2.0000000000003926, trainable=True) grad:7.460698725481052e-14
# ------------------------Tensor(data=2, trainable=False) grad:7.460698725482516e-14
# ------------------------Tensor(data=1.0000000000001963, trainable=True) grad:2.7533531010703882e-14
# --------------------Tensor(data=3.999999999999682, trainable=True) grad:-4.707345624410664e-14
# ----------------Tensor(data=6, trainable=False) grad:-7.460698725481052e-14
# Tensor(data=9.865494480693974e-27, trainable=True) grad:1.0
# ----Tensor(data=1.9730988961387947e-26, trainable=True) grad:0.5
# --------Tensor(data=5.566202547239459e-27, trainable=True) grad:0.5
# ------------Tensor(data=7.460698725481052e-14, trainable=True) grad:7.460698725481052e-14
# ----------------Tensor(data=6, trainable=False) grad:-7.460698725481052e-14
# ----------------Tensor(data=6.000000000000075, trainable=True) grad:7.460698725481052e-14
# --------------------Tensor(data=2.0000000000003872, trainable=True) grad:7.460698725481052e-14
# ------------------------Tensor(data=2, trainable=False) grad:7.460698725482496e-14
# ------------------------Tensor(data=1.0000000000001936, trainable=True) grad:3.019806626980426e-14
# --------------------Tensor(data=3.999999999999687, trainable=True) grad:-4.440892098500626e-14
# --------Tensor(data=1.4164786414148488e-26, trainable=True) grad:0.5
# ------------Tensor(data=0, trainable=False) grad:0.5
# ------------Tensor(data=1.4164786414148488e-26, trainable=True) grad:0.5
# ----------------Tensor(data=-1.1901590823981678e-13, trainable=True) grad:-1.1901590823981678e-13
# --------------------Tensor(data=5, trainable=False) grad:1.1901590823981678e-13
# --------------------Tensor(data=4.999999999999881, trainable=True) grad:-1.1901590823981678e-13
# ------------------------Tensor(data=1.0000000000001936, trainable=True) grad:-1.1901590823981678e-13
# ----------------------------Tensor(data=1, trainable=False) grad:-1.1901590823983983e-13
# ----------------------------Tensor(data=1.0000000000001936, trainable=True) grad:3.019806626980426e-14
# ------------------------Tensor(data=3.999999999999687, trainable=True) grad:-4.440892098500626e-14
# ----Tensor(data=2, trainable=False) grad:-4.932747240346987e-27
# Tensor(data=9.62923063958028e-27, trainable=True) grad:1.0
# ----Tensor(data=1.925846127916056e-26, trainable=True) grad:0.5
# --------Tensor(data=1.3954160552454478e-26, trainable=True) grad:0.5
# ------------Tensor(data=0, trainable=False) grad:0.5
# ------------Tensor(data=1.3954160552454478e-26, trainable=True) grad:0.5
# ----------------Tensor(data=-1.1812772982011666e-13, trainable=True) grad:-1.1812772982011666e-13
# --------------------Tensor(data=5, trainable=False) grad:1.1812772982011666e-13
# --------------------Tensor(data=4.999999999999882, trainable=True) grad:-1.1812772982011666e-13
# ------------------------Tensor(data=3.9999999999996914, trainable=True) grad:-4.529709940470639e-14
# ------------------------Tensor(data=1.0000000000001905, trainable=True) grad:-1.1812772982011666e-13
# ----------------------------Tensor(data=1.0000000000001905, trainable=True) grad:2.7533531010703882e-14
# ----------------------------Tensor(data=1, trainable=False) grad:-1.1812772982013917e-13
# --------Tensor(data=5.3043007267060834e-27, trainable=True) grad:0.5
# ------------Tensor(data=7.283063041541027e-14, trainable=True) grad:7.283063041541027e-14
# ----------------Tensor(data=6, trainable=False) grad:-7.283063041541027e-14
# ----------------Tensor(data=6.000000000000073, trainable=True) grad:7.283063041541027e-14
# --------------------Tensor(data=2.000000000000381, trainable=True) grad:7.283063041541027e-14
# ------------------------Tensor(data=1.0000000000001905, trainable=True) grad:2.7533531010703882e-14
# ------------------------Tensor(data=2, trainable=False) grad:7.283063041542414e-14
# --------------------Tensor(data=3.9999999999996914, trainable=True) grad:-4.529709940470639e-14
# ----Tensor(data=2, trainable=False) grad:-4.81461531979014e-27
# Tensor(data=9.29317589395613e-27, trainable=True) grad:1.0
# ----Tensor(data=2, trainable=False) grad:-4.646587946978065e-27
# ----Tensor(data=1.858635178791226e-26, trainable=True) grad:0.5
# --------Tensor(data=5.0487097934144756e-27, trainable=True) grad:0.5
# ------------Tensor(data=7.105427357601002e-14, trainable=True) grad:7.105427357601002e-14
# ----------------Tensor(data=6.000000000000071, trainable=True) grad:7.105427357601002e-14
# --------------------Tensor(data=2.0000000000003757, trainable=True) grad:7.105427357601002e-14
# ------------------------Tensor(data=1.0000000000001878, trainable=True) grad:2.5757174171303632e-14
# ------------------------Tensor(data=2, trainable=False) grad:7.105427357602337e-14
# --------------------Tensor(data=3.999999999999696, trainable=True) grad:-4.529709940470639e-14
# ----------------Tensor(data=6, trainable=False) grad:-7.105427357601002e-14
# --------Tensor(data=1.3537641994497784e-26, trainable=True) grad:0.5
# ------------Tensor(data=0, trainable=False) grad:0.5
# ------------Tensor(data=1.3537641994497784e-26, trainable=True) grad:0.5
# ----------------Tensor(data=-1.163513729807164e-13, trainable=True) grad:-1.163513729807164e-13
# --------------------Tensor(data=5, trainable=False) grad:1.163513729807164e-13
# --------------------Tensor(data=4.999999999999884, trainable=True) grad:-1.163513729807164e-13
# ------------------------Tensor(data=3.999999999999696, trainable=True) grad:-4.529709940470639e-14
# ------------------------Tensor(data=1.0000000000001878, trainable=True) grad:-1.163513729807164e-13
# ----------------------------Tensor(data=1, trainable=False) grad:-1.1635137298073827e-13
# ----------------------------Tensor(data=1.0000000000001878, trainable=True) grad:2.5757174171303632e-14
# Tensor(data=9.088072058598667e-27, trainable=True) grad:1.0
# ----Tensor(data=1.8176144117197333e-26, trainable=True) grad:0.5
# --------Tensor(data=5.0487097934144756e-27, trainable=True) grad:0.5
# ------------Tensor(data=7.105427357601002e-14, trainable=True) grad:7.105427357601002e-14
# ----------------Tensor(data=6.000000000000071, trainable=True) grad:7.105427357601002e-14
# --------------------Tensor(data=2.0000000000003704, trainable=True) grad:7.105427357601002e-14
# ------------------------Tensor(data=2, trainable=False) grad:7.105427357602317e-14
# ------------------------Tensor(data=1.0000000000001852, trainable=True) grad:2.7533531010703882e-14
# --------------------Tensor(data=3.9999999999997002, trainable=True) grad:-4.3520742565306136e-14
# ----------------Tensor(data=6, trainable=False) grad:-7.105427357601002e-14
# --------Tensor(data=1.3127434323782857e-26, trainable=True) grad:0.5
# ------------Tensor(data=0, trainable=False) grad:0.5
# ------------Tensor(data=1.3127434323782857e-26, trainable=True) grad:0.5
# ----------------Tensor(data=-1.1457501614131615e-13, trainable=True) grad:-1.1457501614131615e-13
# --------------------Tensor(data=4.999999999999885, trainable=True) grad:-1.1457501614131615e-13
# ------------------------Tensor(data=1.0000000000001852, trainable=True) grad:-1.1457501614131615e-13
# ----------------------------Tensor(data=1.0000000000001852, trainable=True) grad:2.7533531010703882e-14
# ----------------------------Tensor(data=1, trainable=False) grad:-1.1457501614133738e-13
# ------------------------Tensor(data=3.9999999999997002, trainable=True) grad:-4.3520742565306136e-14
# --------------------Tensor(data=5, trainable=False) grad:1.1457501614131615e-13
# ----Tensor(data=2, trainable=False) grad:-4.544036029299333e-27
# Epoch 20/2000, Loss: Tensor(data=-0.1, trainable=True)
# Tensor(data=8.761483643837168e-27, trainable=True) grad:1.0
# ----Tensor(data=1.7522967287674335e-26, trainable=True) grad:0.5
# --------Tensor(data=4.799429747364636e-27, trainable=True) grad:0.5
# ------------Tensor(data=6.927791673660977e-14, trainable=True) grad:6.927791673660977e-14
# ----------------Tensor(data=6, trainable=False) grad:-6.927791673660977e-14
# ----------------Tensor(data=6.000000000000069, trainable=True) grad:6.927791673660977e-14
# --------------------Tensor(data=2.000000000000365, trainable=True) grad:6.927791673660977e-14
# ------------------------Tensor(data=1.0000000000001825, trainable=True) grad:2.5757174171303632e-14
# ------------------------Tensor(data=2, trainable=False) grad:6.927791673662242e-14
# --------------------Tensor(data=3.9999999999997047, trainable=True) grad:-4.3520742565306136e-14
# --------Tensor(data=1.27235375403097e-26, trainable=True) grad:0.5
# ------------Tensor(data=1.27235375403097e-26, trainable=True) grad:0.5
# ----------------Tensor(data=-1.127986593019159e-13, trainable=True) grad:-1.127986593019159e-13
# --------------------Tensor(data=5, trainable=False) grad:1.127986593019159e-13
# --------------------Tensor(data=4.999999999999887, trainable=True) grad:-1.127986593019159e-13
# ------------------------Tensor(data=1.0000000000001825, trainable=True) grad:-1.127986593019159e-13
# ----------------------------Tensor(data=1.0000000000001825, trainable=True) grad:2.5757174171303632e-14
# ----------------------------Tensor(data=1, trainable=False) grad:-1.1279865930193649e-13
# ------------------------Tensor(data=3.9999999999997047, trainable=True) grad:-4.3520742565306136e-14
# ------------Tensor(data=0, trainable=False) grad:0.5
# ----Tensor(data=2, trainable=False) grad:-4.380741821918584e-27
# Tensor(data=8.562690695721473e-27, trainable=True) grad:1.0
# ----Tensor(data=2, trainable=False) grad:-4.281345347860736e-27
# ----Tensor(data=1.7125381391442945e-26, trainable=True) grad:0.5
# --------Tensor(data=1.232595164407831e-26, trainable=True) grad:0.5
# ------------Tensor(data=1.232595164407831e-26, trainable=True) grad:0.5
# ----------------Tensor(data=-1.1102230246251565e-13, trainable=True) grad:-1.1102230246251565e-13
# --------------------Tensor(data=4.999999999999889, trainable=True) grad:-1.1102230246251565e-13
# ------------------------Tensor(data=1.0000000000001799, trainable=True) grad:-1.1102230246251565e-13
# ----------------------------Tensor(data=1, trainable=False) grad:-1.1102230246253562e-13
# ----------------------------Tensor(data=1.0000000000001799, trainable=True) grad:2.7533531010703882e-14
# ------------------------Tensor(data=3.999999999999709, trainable=True) grad:-4.1744385725905886e-14
# --------------------Tensor(data=5, trainable=False) grad:1.1102230246251565e-13
# ------------Tensor(data=0, trainable=False) grad:0.5
# --------Tensor(data=4.799429747364636e-27, trainable=True) grad:0.5
# ------------Tensor(data=6.927791673660977e-14, trainable=True) grad:6.927791673660977e-14
# ----------------Tensor(data=6.000000000000069, trainable=True) grad:6.927791673660977e-14
# --------------------Tensor(data=3.999999999999709, trainable=True) grad:-4.1744385725905886e-14
# --------------------Tensor(data=2.0000000000003597, trainable=True) grad:6.927791673660977e-14
# ------------------------Tensor(data=2, trainable=False) grad:6.927791673662223e-14
# ------------------------Tensor(data=1.0000000000001799, trainable=True) grad:2.7533531010703882e-14
# ----------------Tensor(data=6, trainable=False) grad:-6.927791673660977e-14
# Tensor(data=8.342992933617421e-27, trainable=True) grad:1.0
# ----Tensor(data=2, trainable=False) grad:-4.1714964668087104e-27
# ----Tensor(data=1.6685985867234842e-26, trainable=True) grad:0.5
# --------Tensor(data=1.2129525278678278e-26, trainable=True) grad:0.5
# ------------Tensor(data=1.2129525278678278e-26, trainable=True) grad:0.5
# ----------------Tensor(data=-1.1013412404281553e-13, trainable=True) grad:-1.1013412404281553e-13
# --------------------Tensor(data=5, trainable=False) grad:1.1013412404281553e-13
# --------------------Tensor(data=4.99999999999989, trainable=True) grad:-1.1013412404281553e-13
# ------------------------Tensor(data=1.0000000000001772, trainable=True) grad:-1.1013412404281553e-13
# ----------------------------Tensor(data=1, trainable=False) grad:-1.1013412404283504e-13
# ----------------------------Tensor(data=1.0000000000001772, trainable=True) grad:2.4868995751603507e-14
# ------------------------Tensor(data=3.999999999999713, trainable=True) grad:-4.263256414560601e-14
# ------------Tensor(data=0, trainable=False) grad:0.5
# --------Tensor(data=4.556460588556564e-27, trainable=True) grad:0.5
# ------------Tensor(data=6.750155989720952e-14, trainable=True) grad:6.750155989720952e-14
# ----------------Tensor(data=6, trainable=False) grad:-6.750155989720952e-14
# ----------------Tensor(data=6.0000000000000675, trainable=True) grad:6.750155989720952e-14
# --------------------Tensor(data=2.0000000000003544, trainable=True) grad:6.750155989720952e-14
# ------------------------Tensor(data=2, trainable=False) grad:6.750155989722148e-14
# ------------------------Tensor(data=1.0000000000001772, trainable=True) grad:2.4868995751603507e-14
# --------------------Tensor(data=3.999999999999713, trainable=True) grad:-4.263256414560601e-14
# Tensor(data=8.053086550948699e-27, trainable=True) grad:1.0
# ----Tensor(data=1.6106173101897398e-26, trainable=True) grad:0.5
# --------Tensor(data=1.1549712513340834e-26, trainable=True) grad:0.5
# ------------Tensor(data=0, trainable=False) grad:0.5
# ------------Tensor(data=1.1549712513340834e-26, trainable=True) grad:0.5
# ----------------Tensor(data=-1.0746958878371515e-13, trainable=True) grad:-1.0746958878371515e-13
# --------------------Tensor(data=4.9999999999998925, trainable=True) grad:-1.0746958878371515e-13
# ------------------------Tensor(data=1.0000000000001747, trainable=True) grad:-1.0746958878371515e-13
# ----------------------------Tensor(data=1, trainable=False) grad:-1.0746958878373393e-13
# ----------------------------Tensor(data=1.0000000000001747, trainable=True) grad:2.7533531010703882e-14
# ------------------------Tensor(data=3.9999999999997176, trainable=True) grad:-3.9968028886505635e-14
# --------------------Tensor(data=5, trainable=False) grad:1.0746958878371515e-13
# --------Tensor(data=4.556460588556564e-27, trainable=True) grad:0.5
# ------------Tensor(data=6.750155989720952e-14, trainable=True) grad:6.750155989720952e-14
# ----------------Tensor(data=6.0000000000000675, trainable=True) grad:6.750155989720952e-14
# --------------------Tensor(data=3.9999999999997176, trainable=True) grad:-3.9968028886505635e-14
# --------------------Tensor(data=2.0000000000003495, trainable=True) grad:6.750155989720952e-14
# ------------------------Tensor(data=2, trainable=False) grad:6.750155989722132e-14
# ------------------------Tensor(data=1.0000000000001747, trainable=True) grad:2.7533531010703882e-14
# ----------------Tensor(data=6, trainable=False) grad:-6.750155989720952e-14
# ----Tensor(data=2, trainable=False) grad:-4.0265432754743495e-27
# Tensor(data=7.839699676086415e-27, trainable=True) grad:1.0
# ----Tensor(data=2, trainable=False) grad:-3.919849838043208e-27
# ----Tensor(data=1.567939935217283e-26, trainable=True) grad:0.5
# --------Tensor(data=1.135959703518257e-26, trainable=True) grad:0.5
# ------------Tensor(data=0, trainable=False) grad:0.5
# ------------Tensor(data=1.135959703518257e-26, trainable=True) grad:0.5
# ----------------Tensor(data=-1.0658141036401503e-13, trainable=True) grad:-1.0658141036401503e-13
# --------------------Tensor(data=5, trainable=False) grad:1.0658141036401503e-13
# --------------------Tensor(data=4.999999999999893, trainable=True) grad:-1.0658141036401503e-13
# ------------------------Tensor(data=1.000000000000172, trainable=True) grad:-1.0658141036401503e-13
# ----------------------------Tensor(data=1, trainable=False) grad:-1.0658141036403337e-13
# ----------------------------Tensor(data=1.000000000000172, trainable=True) grad:2.4868995751603507e-14
# ------------------------Tensor(data=3.9999999999997216, trainable=True) grad:-4.085620730620576e-14
# --------Tensor(data=4.319802316990261e-27, trainable=True) grad:0.5
# ------------Tensor(data=6.572520305780927e-14, trainable=True) grad:6.572520305780927e-14
# ----------------Tensor(data=6, trainable=False) grad:-6.572520305780927e-14
# ----------------Tensor(data=6.000000000000066, trainable=True) grad:6.572520305780927e-14
# --------------------Tensor(data=3.9999999999997216, trainable=True) grad:-4.085620730620576e-14
# --------------------Tensor(data=2.000000000000344, trainable=True) grad:6.572520305780927e-14
# ------------------------Tensor(data=2, trainable=False) grad:6.572520305782058e-14
# ------------------------Tensor(data=1.000000000000172, trainable=True) grad:2.4868995751603507e-14
# Tensor(data=7.59396950411007e-27, trainable=True) grad:1.0
# ----Tensor(data=2, trainable=False) grad:-3.796984752055035e-27
# ----Tensor(data=1.518793900822014e-26, trainable=True) grad:0.5
# --------Tensor(data=1.0984099244297368e-26, trainable=True) grad:0.5
# ------------Tensor(data=1.0984099244297368e-26, trainable=True) grad:0.5
# ----------------Tensor(data=-1.0480505352461478e-13, trainable=True) grad:-1.0480505352461478e-13
# --------------------Tensor(data=5, trainable=False) grad:1.0480505352461478e-13
# --------------------Tensor(data=4.999999999999895, trainable=True) grad:-1.0480505352461478e-13
# ------------------------Tensor(data=3.9999999999997256, trainable=True) grad:-3.9968028886505635e-14
# ------------------------Tensor(data=1.0000000000001696, trainable=True) grad:-1.0480505352461478e-13
# ----------------------------Tensor(data=1, trainable=False) grad:-1.0480505352463256e-13
# ----------------------------Tensor(data=1.0000000000001696, trainable=True) grad:2.4868995751603507e-14
# ------------Tensor(data=0, trainable=False) grad:0.5
# --------Tensor(data=4.203839763922772e-27, trainable=True) grad:0.5
# ------------Tensor(data=6.483702463810914e-14, trainable=True) grad:6.483702463810914e-14
# ----------------Tensor(data=6, trainable=False) grad:-6.483702463810914e-14
# ----------------Tensor(data=6.000000000000065, trainable=True) grad:6.483702463810914e-14
# --------------------Tensor(data=3.9999999999997256, trainable=True) grad:-3.9968028886505635e-14
# --------------------Tensor(data=2.0000000000003393, trainable=True) grad:6.483702463810914e-14
# ------------------------Tensor(data=2, trainable=False) grad:6.483702463812014e-14
# ------------------------Tensor(data=1.0000000000001696, trainable=True) grad:2.4868995751603507e-14
# Tensor(data=7.35218363665983e-27, trainable=True) grad:1.0
# ----Tensor(data=2, trainable=False) grad:-3.676091818329915e-27
# ----Tensor(data=1.470436727331966e-26, trainable=True) grad:0.5
# --------Tensor(data=4.089454932665725e-27, trainable=True) grad:0.5
# ------------Tensor(data=6.394884621840902e-14, trainable=True) grad:6.394884621840902e-14
# ----------------Tensor(data=6.000000000000064, trainable=True) grad:6.394884621840902e-14
# --------------------Tensor(data=2.0000000000003344, trainable=True) grad:6.394884621840902e-14
# ------------------------Tensor(data=1.0000000000001672, trainable=True) grad:2.4868995751603507e-14
# ------------------------Tensor(data=2, trainable=False) grad:6.394884621841971e-14
# ...
# --------------------Tensor(data=3.999999999999988, trainable=True) grad:-1.7763568394002505e-15
# ----------------Tensor(data=6, trainable=False) grad:-2.6645352591003757e-15
# ----Tensor(data=2, trainable=False) grad:-6.7053176943786e-30
# Epoch 1990/2000, Loss: Tensor(data=-0.1, trainable=True)
# Tensor(data=1.34106353887572e-29, trainable=True) grad:1.0
# ----Tensor(data=2, trainable=False) grad:-6.7053176943786e-30
# ----Tensor(data=2.68212707775144e-29, trainable=True) grad:0.5
# --------Tensor(data=1.9721522630525295e-29, trainable=True) grad:0.5
# ------------Tensor(data=0, trainable=False) grad:0.5
# ------------Tensor(data=1.9721522630525295e-29, trainable=True) grad:0.5
# ----------------Tensor(data=-4.440892098500626e-15, trainable=True) grad:-4.440892098500626e-15
# --------------------Tensor(data=5, trainable=False) grad:4.440892098500626e-15
# --------------------Tensor(data=4.999999999999996, trainable=True) grad:-4.440892098500626e-15
# ------------------------Tensor(data=3.999999999999988, trainable=True) grad:-1.7763568394002505e-15
# ------------------------Tensor(data=1.0000000000000073, trainable=True) grad:-4.440892098500626e-15
# ----------------------------Tensor(data=1, trainable=False) grad:-4.4408920985006585e-15
# ----------------------------Tensor(data=1.0000000000000073, trainable=True) grad:8.881784197001252e-16
# --------Tensor(data=7.099748146989106e-30, trainable=True) grad:0.5
# ------------Tensor(data=2.6645352591003757e-15, trainable=True) grad:2.6645352591003757e-15
# ----------------Tensor(data=6.000000000000003, trainable=True) grad:2.6645352591003757e-15
# --------------------Tensor(data=3.999999999999988, trainable=True) grad:-1.7763568394002505e-15
# --------------------Tensor(data=2.0000000000000147, trainable=True) grad:2.6645352591003757e-15
# ------------------------Tensor(data=2, trainable=False) grad:2.6645352591003954e-15
# ------------------------Tensor(data=1.0000000000000073, trainable=True) grad:8.881784197001252e-16
# ----------------Tensor(data=6, trainable=False) grad:-2.6645352591003757e-15
# Tensor(data=1.34106353887572e-29, trainable=True) grad:1.0
# ----Tensor(data=2, trainable=False) grad:-6.7053176943786e-30
# ----Tensor(data=2.68212707775144e-29, trainable=True) grad:0.5
# --------Tensor(data=1.9721522630525295e-29, trainable=True) grad:0.5
# ------------Tensor(data=0, trainable=False) grad:0.5
# ------------Tensor(data=1.9721522630525295e-29, trainable=True) grad:0.5
# ----------------Tensor(data=-4.440892098500626e-15, trainable=True) grad:-4.440892098500626e-15
# --------------------Tensor(data=5, trainable=False) grad:4.440892098500626e-15
# --------------------Tensor(data=4.999999999999996, trainable=True) grad:-4.440892098500626e-15
# ------------------------Tensor(data=1.0000000000000073, trainable=True) grad:-4.440892098500626e-15
# ----------------------------Tensor(data=1, trainable=False) grad:-4.4408920985006585e-15
# ----------------------------Tensor(data=1.0000000000000073, trainable=True) grad:8.881784197001252e-16
# ------------------------Tensor(data=3.999999999999988, trainable=True) grad:-1.7763568394002505e-15
# --------Tensor(data=7.099748146989106e-30, trainable=True) grad:0.5
# ------------Tensor(data=2.6645352591003757e-15, trainable=True) grad:2.6645352591003757e-15
# ----------------Tensor(data=6.000000000000003, trainable=True) grad:2.6645352591003757e-15
# --------------------Tensor(data=3.999999999999988, trainable=True) grad:-1.7763568394002505e-15
# --------------------Tensor(data=2.0000000000000147, trainable=True) grad:2.6645352591003757e-15
# ------------------------Tensor(data=2, trainable=False) grad:2.6645352591003954e-15
# ------------------------Tensor(data=1.0000000000000073, trainable=True) grad:8.881784197001252e-16
# ----------------Tensor(data=6, trainable=False) grad:-2.6645352591003757e-15
# Tensor(data=1.34106353887572e-29, trainable=True) grad:1.0
# ----Tensor(data=2, trainable=False) grad:-6.7053176943786e-30
# ----Tensor(data=2.68212707775144e-29, trainable=True) grad:0.5
# --------Tensor(data=1.9721522630525295e-29, trainable=True) grad:0.5
# ------------Tensor(data=0, trainable=False) grad:0.5
# ------------Tensor(data=1.9721522630525295e-29, trainable=True) grad:0.5
# ----------------Tensor(data=-4.440892098500626e-15, trainable=True) grad:-4.440892098500626e-15
# --------------------Tensor(data=4.999999999999996, trainable=True) grad:-4.440892098500626e-15
# ------------------------Tensor(data=1.0000000000000073, trainable=True) grad:-4.440892098500626e-15
# ----------------------------Tensor(data=1, trainable=False) grad:-4.4408920985006585e-15
# ----------------------------Tensor(data=1.0000000000000073, trainable=True) grad:8.881784197001252e-16
# ------------------------Tensor(data=3.999999999999988, trainable=True) grad:-1.7763568394002505e-15
# --------------------Tensor(data=5, trainable=False) grad:4.440892098500626e-15
# --------Tensor(data=7.099748146989106e-30, trainable=True) grad:0.5
# ------------Tensor(data=2.6645352591003757e-15, trainable=True) grad:2.6645352591003757e-15
# ----------------Tensor(data=6, trainable=False) grad:-2.6645352591003757e-15
# ----------------Tensor(data=6.000000000000003, trainable=True) grad:2.6645352591003757e-15
# --------------------Tensor(data=3.999999999999988, trainable=True) grad:-1.7763568394002505e-15
# --------------------Tensor(data=2.0000000000000147, trainable=True) grad:2.6645352591003757e-15
# ------------------------Tensor(data=1.0000000000000073, trainable=True) grad:8.881784197001252e-16
# ------------------------Tensor(data=2, trainable=False) grad:2.6645352591003954e-15
# Tensor(data=1.34106353887572e-29, trainable=True) grad:1.0
# ----Tensor(data=2.68212707775144e-29, trainable=True) grad:0.5
# --------Tensor(data=1.9721522630525295e-29, trainable=True) grad:0.5
# ------------Tensor(data=0, trainable=False) grad:0.5
# ------------Tensor(data=1.9721522630525295e-29, trainable=True) grad:0.5
# ----------------Tensor(data=-4.440892098500626e-15, trainable=True) grad:-4.440892098500626e-15
# --------------------Tensor(data=5, trainable=False) grad:4.440892098500626e-15
# --------------------Tensor(data=4.999999999999996, trainable=True) grad:-4.440892098500626e-15
# ------------------------Tensor(data=3.999999999999988, trainable=True) grad:-1.7763568394002505e-15
# ------------------------Tensor(data=1.0000000000000073, trainable=True) grad:-4.440892098500626e-15
# ----------------------------Tensor(data=1, trainable=False) grad:-4.4408920985006585e-15
# ----------------------------Tensor(data=1.0000000000000073, trainable=True) grad:8.881784197001252e-16
# --------Tensor(data=7.099748146989106e-30, trainable=True) grad:0.5
# ------------Tensor(data=2.6645352591003757e-15, trainable=True) grad:2.6645352591003757e-15
# ----------------Tensor(data=6, trainable=False) grad:-2.6645352591003757e-15
# ----------------Tensor(data=6.000000000000003, trainable=True) grad:2.6645352591003757e-15
# --------------------Tensor(data=3.999999999999988, trainable=True) grad:-1.7763568394002505e-15
# --------------------Tensor(data=2.0000000000000147, trainable=True) grad:2.6645352591003757e-15
# ------------------------Tensor(data=2, trainable=False) grad:2.6645352591003954e-15
# ------------------------Tensor(data=1.0000000000000073, trainable=True) grad:8.881784197001252e-16
# ----Tensor(data=2, trainable=False) grad:-6.7053176943786e-30
# Tensor(data=1.34106353887572e-29, trainable=True) grad:1.0
# ----Tensor(data=2, trainable=False) grad:-6.7053176943786e-30
# ----Tensor(data=2.68212707775144e-29, trainable=True) grad:0.5
# --------Tensor(data=7.099748146989106e-30, trainable=True) grad:0.5
# ------------Tensor(data=2.6645352591003757e-15, trainable=True) grad:2.6645352591003757e-15
# ----------------Tensor(data=6, trainable=False) grad:-2.6645352591003757e-15
# ----------------Tensor(data=6.000000000000003, trainable=True) grad:2.6645352591003757e-15
# --------------------Tensor(data=2.0000000000000147, trainable=True) grad:2.6645352591003757e-15
# ------------------------Tensor(data=1.0000000000000073, trainable=True) grad:8.881784197001252e-16
# ------------------------Tensor(data=2, trainable=False) grad:2.6645352591003954e-15
# --------------------Tensor(data=3.999999999999988, trainable=True) grad:-1.7763568394002505e-15
# --------Tensor(data=1.9721522630525295e-29, trainable=True) grad:0.5
# ------------Tensor(data=1.9721522630525295e-29, trainable=True) grad:0.5
# ----------------Tensor(data=-4.440892098500626e-15, trainable=True) grad:-4.440892098500626e-15
# --------------------Tensor(data=4.999999999999996, trainable=True) grad:-4.440892098500626e-15
# ------------------------Tensor(data=3.999999999999988, trainable=True) grad:-1.7763568394002505e-15
# ------------------------Tensor(data=1.0000000000000073, trainable=True) grad:-4.440892098500626e-15
# ----------------------------Tensor(data=1, trainable=False) grad:-4.4408920985006585e-15
# ----------------------------Tensor(data=1.0000000000000073, trainable=True) grad:8.881784197001252e-16
# --------------------Tensor(data=5, trainable=False) grad:4.440892098500626e-15
# ------------Tensor(data=0, trainable=False) grad:0.5
# Tensor(data=1.34106353887572e-29, trainable=True) grad:1.0
# ----Tensor(data=2, trainable=False) grad:-6.7053176943786e-30
# ----Tensor(data=2.68212707775144e-29, trainable=True) grad:0.5
# --------Tensor(data=1.9721522630525295e-29, trainable=True) grad:0.5
# ------------Tensor(data=0, trainable=False) grad:0.5
# ------------Tensor(data=1.9721522630525295e-29, trainable=True) grad:0.5
# ----------------Tensor(data=-4.440892098500626e-15, trainable=True) grad:-4.440892098500626e-15
# --------------------Tensor(data=5, trainable=False) grad:4.440892098500626e-15
# --------------------Tensor(data=4.999999999999996, trainable=True) grad:-4.440892098500626e-15
# ------------------------Tensor(data=3.999999999999988, trainable=True) grad:-1.7763568394002505e-15
# ------------------------Tensor(data=1.0000000000000073, trainable=True) grad:-4.440892098500626e-15
# ----------------------------Tensor(data=1, trainable=False) grad:-4.4408920985006585e-15
# ----------------------------Tensor(data=1.0000000000000073, trainable=True) grad:8.881784197001252e-16
# --------Tensor(data=7.099748146989106e-30, trainable=True) grad:0.5
# ------------Tensor(data=2.6645352591003757e-15, trainable=True) grad:2.6645352591003757e-15
# ----------------Tensor(data=6, trainable=False) grad:-2.6645352591003757e-15
# ----------------Tensor(data=6.000000000000003, trainable=True) grad:2.6645352591003757e-15
# --------------------Tensor(data=2.0000000000000147, trainable=True) grad:2.6645352591003757e-15
# ------------------------Tensor(data=2, trainable=False) grad:2.6645352591003954e-15
# ------------------------Tensor(data=1.0000000000000073, trainable=True) grad:8.881784197001252e-16
# --------------------Tensor(data=3.999999999999988, trainable=True) grad:-1.7763568394002505e-15
# Tensor(data=1.34106353887572e-29, trainable=True) grad:1.0
# ----Tensor(data=2.68212707775144e-29, trainable=True) grad:0.5
# --------Tensor(data=1.9721522630525295e-29, trainable=True) grad:0.5
# ------------Tensor(data=0, trainable=False) grad:0.5
# ------------Tensor(data=1.9721522630525295e-29, trainable=True) grad:0.5
# ----------------Tensor(data=-4.440892098500626e-15, trainable=True) grad:-4.440892098500626e-15
# --------------------Tensor(data=4.999999999999996, trainable=True) grad:-4.440892098500626e-15
# ------------------------Tensor(data=3.999999999999988, trainable=True) grad:-1.7763568394002505e-15
# ------------------------Tensor(data=1.0000000000000073, trainable=True) grad:-4.440892098500626e-15
# ----------------------------Tensor(data=1.0000000000000073, trainable=True) grad:8.881784197001252e-16
# ----------------------------Tensor(data=1, trainable=False) grad:-4.4408920985006585e-15
# --------------------Tensor(data=5, trainable=False) grad:4.440892098500626e-15
# --------Tensor(data=7.099748146989106e-30, trainable=True) grad:0.5
# ------------Tensor(data=2.6645352591003757e-15, trainable=True) grad:2.6645352591003757e-15
# ----------------Tensor(data=6.000000000000003, trainable=True) grad:2.6645352591003757e-15
# --------------------Tensor(data=3.999999999999988, trainable=True) grad:-1.7763568394002505e-15
# --------------------Tensor(data=2.0000000000000147, trainable=True) grad:2.6645352591003757e-15
# ------------------------Tensor(data=2, trainable=False) grad:2.6645352591003954e-15
# ------------------------Tensor(data=1.0000000000000073, trainable=True) grad:8.881784197001252e-16
# ----------------Tensor(data=6, trainable=False) grad:-2.6645352591003757e-15
# ----Tensor(data=2, trainable=False) grad:-6.7053176943786e-30
# Tensor(data=1.34106353887572e-29, trainable=True) grad:1.0
# ----Tensor(data=2, trainable=False) grad:-6.7053176943786e-30
# ----Tensor(data=2.68212707775144e-29, trainable=True) grad:0.5
# --------Tensor(data=1.9721522630525295e-29, trainable=True) grad:0.5
# ------------Tensor(data=0, trainable=False) grad:0.5
# ------------Tensor(data=1.9721522630525295e-29, trainable=True) grad:0.5
# ----------------Tensor(data=-4.440892098500626e-15, trainable=True) grad:-4.440892098500626e-15
# --------------------Tensor(data=5, trainable=False) grad:4.440892098500626e-15
# --------------------Tensor(data=4.999999999999996, trainable=True) grad:-4.440892098500626e-15
# ------------------------Tensor(data=3.999999999999988, trainable=True) grad:-1.7763568394002505e-15
# ------------------------Tensor(data=1.0000000000000073, trainable=True) grad:-4.440892098500626e-15
# ----------------------------Tensor(data=1, trainable=False) grad:-4.4408920985006585e-15
# ----------------------------Tensor(data=1.0000000000000073, trainable=True) grad:8.881784197001252e-16
# --------Tensor(data=7.099748146989106e-30, trainable=True) grad:0.5
# ------------Tensor(data=2.6645352591003757e-15, trainable=True) grad:2.6645352591003757e-15
# ----------------Tensor(data=6.000000000000003, trainable=True) grad:2.6645352591003757e-15
# --------------------Tensor(data=2.0000000000000147, trainable=True) grad:2.6645352591003757e-15
# ------------------------Tensor(data=2, trainable=False) grad:2.6645352591003954e-15
# ------------------------Tensor(data=1.0000000000000073, trainable=True) grad:8.881784197001252e-16
# --------------------Tensor(data=3.999999999999988, trainable=True) grad:-1.7763568394002505e-15
# ----------------Tensor(data=6, trainable=False) grad:-2.6645352591003757e-15
# Tensor(data=1.34106353887572e-29, trainable=True) grad:1.0
# ----Tensor(data=2, trainable=False) grad:-6.7053176943786e-30
# ----Tensor(data=2.68212707775144e-29, trainable=True) grad:0.5
# --------Tensor(data=1.9721522630525295e-29, trainable=True) grad:0.5
# ------------Tensor(data=0, trainable=False) grad:0.5
# ------------Tensor(data=1.9721522630525295e-29, trainable=True) grad:0.5
# ----------------Tensor(data=-4.440892098500626e-15, trainable=True) grad:-4.440892098500626e-15
# --------------------Tensor(data=5, trainable=False) grad:4.440892098500626e-15
# --------------------Tensor(data=4.999999999999996, trainable=True) grad:-4.440892098500626e-15
# ------------------------Tensor(data=1.0000000000000073, trainable=True) grad:-4.440892098500626e-15
# ----------------------------Tensor(data=1, trainable=False) grad:-4.4408920985006585e-15
# ----------------------------Tensor(data=1.0000000000000073, trainable=True) grad:8.881784197001252e-16
# ------------------------Tensor(data=3.999999999999988, trainable=True) grad:-1.7763568394002505e-15
# --------Tensor(data=7.099748146989106e-30, trainable=True) grad:0.5
# ------------Tensor(data=2.6645352591003757e-15, trainable=True) grad:2.6645352591003757e-15
# ----------------Tensor(data=6.000000000000003, trainable=True) grad:2.6645352591003757e-15
# --------------------Tensor(data=3.999999999999988, trainable=True) grad:-1.7763568394002505e-15
# --------------------Tensor(data=2.0000000000000147, trainable=True) grad:2.6645352591003757e-15
# ------------------------Tensor(data=1.0000000000000073, trainable=True) grad:8.881784197001252e-16
# ------------------------Tensor(data=2, trainable=False) grad:2.6645352591003954e-15
# ----------------Tensor(data=6, trainable=False) grad:-2.6645352591003757e-15

# %% [markdown]
# 可以看到，最后a的值被算出是1.0000000000000073，b的值被算出是3.999999999999988，和真值：1，4非常接近，求解成功

# %% [markdown]
# 现在，让我们用我们本节编写的程序实现上节的遗留问题，我们先制作训练集和测试集，训练集是用于训练模型的，测试集是用于检验模型训练质量的，我们会随机在生成的数据集上选择80个点为训练集，20个点为测试集

# %%
def func(x):
    return 4*x*x - 5

# %%
import numpy as np

x_values = np.linspace(-10, 10, 30)
y_values = func(x_values)

# Randomly choosing training data
random_indices = np.random.choice(len(x_values), size=20, replace=False)
train_x = x_values[random_indices]
train_y = y_values[random_indices]

# The remaining data can be considered as the testing dataset
test_x = np.delete(x_values, random_indices)
test_y = np.delete(y_values, random_indices)

# %% [markdown]
# 让我们看看我们制作的训练集和测试集分布

# %%
import matplotlib.pyplot as plt

plt.scatter(train_x, train_y, label='Training Data')
plt.scatter(test_x, test_y, color='r', label='Testing Data')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Quadratic Function and Datasets')
plt.legend()
plt.show()

# %%
import random
w1 = [Tensor(random.random()) for _ in range(10)]
b1 = [Tensor(random.random()) for _ in range(10)]
w2 = [Tensor(random.random()) for _ in range(10)]
b2 = Tensor(random.random())
epoch = 5000
def forward(x):
    temp1 = [w1[i]*x+b1[i] for i in range(len(w1))]
    temp2 = [temp1[i].relu() for i in range(len(temp1))]
    res = 0
    for i in range(len(temp2)):
        res += temp2[i]*w2[i]
    res += b2
    return res
for i in range(epoch):
    loss = 0
    for j in range(len(train_x)):
        y = forward(train_x[j])
        loss += (train_y[j]-y)**2
    loss = loss/len(train_x)
    loss.backward()
    loss.gradient_descent_opt(learning_rate=0.001)
    if i % 100 == 0:
        print(f'Epoch {i}/{epoch}, Loss: {loss}')
# Out:
# Epoch 0/5000, Loss: Tensor(data=29667.183076041892, trainable=True)
# Epoch 100/5000, Loss: Tensor(data=2261.7079220398946, trainable=True)
# Epoch 200/5000, Loss: Tensor(data=2192.4359649653793, trainable=True)
# Epoch 300/5000, Loss: Tensor(data=1999.2738353809282, trainable=True)
# Epoch 400/5000, Loss: Tensor(data=1858.7962989816444, trainable=True)
# Epoch 500/5000, Loss: Tensor(data=1769.8991241386807, trainable=True)
# Epoch 600/5000, Loss: Tensor(data=1703.1538819053744, trainable=True)
# Epoch 700/5000, Loss: Tensor(data=1645.5290961473036, trainable=True)
# Epoch 800/5000, Loss: Tensor(data=1587.8301749803475, trainable=True)
# Epoch 900/5000, Loss: Tensor(data=1560.631974171015, trainable=True)
# Epoch 1000/5000, Loss: Tensor(data=1395.1241601882598, trainable=True)
# Epoch 1100/5000, Loss: Tensor(data=1340.5904433868836, trainable=True)
# Epoch 1200/5000, Loss: Tensor(data=1342.1457495951372, trainable=True)
# Epoch 1300/5000, Loss: Tensor(data=1328.19975191992, trainable=True)
# Epoch 1400/5000, Loss: Tensor(data=1280.4995196496336, trainable=True)
# Epoch 1500/5000, Loss: Tensor(data=1257.742895947007, trainable=True)
# Epoch 1600/5000, Loss: Tensor(data=1232.154012922482, trainable=True)
# Epoch 1700/5000, Loss: Tensor(data=1207.755773848795, trainable=True)
# Epoch 1800/5000, Loss: Tensor(data=1186.1586065871652, trainable=True)
# Epoch 1900/5000, Loss: Tensor(data=1166.0200740951316, trainable=True)
# Epoch 2000/5000, Loss: Tensor(data=1147.2839407873428, trainable=True)
# Epoch 2100/5000, Loss: Tensor(data=1129.9588673463293, trainable=True)
# Epoch 2200/5000, Loss: Tensor(data=1113.9228840766484, trainable=True)
# Epoch 2300/5000, Loss: Tensor(data=1099.0248600912246, trainable=True)
# Epoch 2400/5000, Loss: Tensor(data=1085.1861497424272, trainable=True)
# Epoch 2500/5000, Loss: Tensor(data=1072.3314105669438, trainable=True)
# Epoch 2600/5000, Loss: Tensor(data=1060.3838568537374, trainable=True)
# Epoch 2700/5000, Loss: Tensor(data=1049.2737235304064, trainable=True)
# Epoch 2800/5000, Loss: Tensor(data=1038.9381423765951, trainable=True)
# Epoch 2900/5000, Loss: Tensor(data=1029.3193908317905, trainable=True)
# Epoch 3000/5000, Loss: Tensor(data=1020.3641618297414, trainable=True)
# Epoch 3100/5000, Loss: Tensor(data=1012.0232394754017, trainable=True)
# Epoch 3200/5000, Loss: Tensor(data=1004.2511857258902, trainable=True)
# Epoch 3300/5000, Loss: Tensor(data=997.0060249782355, trainable=True)
# Epoch 3400/5000, Loss: Tensor(data=990.2489582147075, trainable=True)
# Epoch 3500/5000, Loss: Tensor(data=983.9441102035934, trainable=True)
# Epoch 3600/5000, Loss: Tensor(data=978.0583031300316, trainable=True)
# Epoch 3700/5000, Loss: Tensor(data=972.5608511086671, trainable=True)
# Epoch 3800/5000, Loss: Tensor(data=967.4233721657856, trainable=True)
# Epoch 3900/5000, Loss: Tensor(data=962.6196154285195, trainable=True)
# Epoch 4000/5000, Loss: Tensor(data=958.125301814836, trainable=True)
# Epoch 4100/5000, Loss: Tensor(data=953.917976850795, trainable=True)
# Epoch 4200/5000, Loss: Tensor(data=949.9768744821566, trainable=True)
# Epoch 4300/5000, Loss: Tensor(data=946.2827909285385, trainable=True)
# Epoch 4400/5000, Loss: Tensor(data=942.8179677663699, trainable=True)
# Epoch 4500/5000, Loss: Tensor(data=939.5659835311037, trainable=True)
# Epoch 4600/5000, Loss: Tensor(data=936.5116532092763, trainable=True)
# Epoch 4700/5000, Loss: Tensor(data=933.6409350538585, trainable=True)
# Epoch 4800/5000, Loss: Tensor(data=930.9408442067732, trainable=True)
# Epoch 4900/5000, Loss: Tensor(data=928.399372653806, trainable=True)

# %%
def draw(f, test_x, test_y):
    import matplotlib.pyplot as plt
    import numpy as np
    # 生成 x 值范围
    x_values = [i * 0.1 for i in range(int(-10/0.1), int(10/0.1))]
    # 计算对应的 y 值
    y_values = [f(x).data for x in x_values]

    # 绘制图像
    plt.plot(x_values, y_values, label='f(x)')
    plt.title('Graph of f(x)')
    plt.xlabel('x')
    plt.ylabel('f(x)')
    plt.legend()  # 显示图例
    plt.grid(True)  # 显示网格
    plt.scatter(test_x, test_y, label='True data')
    plt.show()

# %%
draw(forward, test_x, test_y)

# %% [markdown]
# 最后我们从本节开始，会附上用标准pytorch实现模型的代码，pytorch将是本教程后面章节的重点，读者可以先熟悉pytorch的代码风格

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
import numpy as np

# Step 2: Define the quadratic function
def quadratic_function(x):
    return 2 * x**2 - 3 * x + 1

# Step 3: Create a dataset
# For simplicity, let's create a dataset with 20 data points between -5 and 5
X_train = torch.linspace(-5, 5, 20).unsqueeze(dim=1)  # Add an extra dimension
y_train = quadratic_function(X_train)

# Step 4: Define a simple neural network model
class SimpleNN(nn.Module):
    def __init__(self):
        super(SimpleNN, self).__init__()
        self.fc1 = nn.Linear(1, 10)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(10, 1)

    def forward(self, x):
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        return x

# Step 5: Define a loss function
criterion = nn.MSELoss()

# Step 6: Train the model
model = SimpleNN()
epochs = 1000

# Step 7: Choose an optimizer
optimizer = optim.SGD(model.parameters(), lr=0.01)

for epoch in range(epochs):
    # Forward pass
    predictions = model(X_train)

    # Compute the loss
    loss = criterion(predictions, y_train)

    # Backward pass and optimization
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if epoch % 100 == 0:
        print(f'Epoch {epoch}/{epochs}, Loss: {loss.item()}')

# Evaluate the trained model
with torch.no_grad():
    X_test = torch.linspace(-6, 6, 100).unsqueeze(dim=1)
    predictions = model(X_test)

# Plot the results
plt.scatter(X_train.numpy(), y_train.numpy(), label='True data')
plt.plot(X_test.numpy(), predictions.numpy(), 'r-', label='Predictions')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# Epoch 0/1000, Loss: 723.5714111328125
# Epoch 100/1000, Loss: 65.84455871582031
# Epoch 200/1000, Loss: 51.168853759765625
# Epoch 300/1000, Loss: 34.91449737548828
# Epoch 400/1000, Loss: 24.89947509765625
# Epoch 500/1000, Loss: 24.177091598510742
# Epoch 600/1000, Loss: 23.86868667602539
# Epoch 700/1000, Loss: 23.467601776123047
# Epoch 800/1000, Loss: 20.106321334838867
# Epoch 900/1000, Loss: 18.34964370727539
